# %%
import os
import numpy as np
import pandas as pd 
from pathlib import Path
import matplotlib.pyplot as plt

# %%
os.chdir("../")

# %%
emission = pd.read_csv('datas\country_emissions.csv',index_col=0)
country_info = pd.read_csv('datas\country_table.csv',index_col=0)

# %%
emission.head()
# Out:
#                   country_name country_code      1990      1991      1992  \
# 1  Africa Eastern and Southern          AFE  0.982975  0.942212  0.907936
# 2                  Afghanistan          AFG  0.191389  0.180674  0.126517
# 3   Africa Western and Central          AFW  0.470111  0.521084  0.558013
# 4                       Angola          AGO  0.554941  0.545807  0.544413
# 5                      Albania          ALB  1.844035  1.261054  0.689644
#
#        1993      1994      1995      1996      1997  ...      2011      2012  \
# 1  0.909550  0.913413  0.933001  0.943200  0.962203  ...  0.976840  0.989585
# 2  0.109106  0.096638  0.088781  0.082267  0.075559  ...  0.408965  0.335061
# 3  0.513859  0.462384  0.492656  0.554305  0.540062  ...  0.451578  0.452101
# 4  0.710961  0.839266  0.914265  1.073630  1.086325  ...  0.983787  0.947583
# 5  0.644008  0.649938  0.612055  0.621206  0.469831  ...  1.768109  1.565921
#
# ...

# %%
country_info.head()
# Out:
#   country_code                 region          incomegroup  \
# 1          AFE         Unknown_Region  Unknown_IncomeGroup
# 2          AFG             South Asia           Low income
# 3          AFW         Unknown_Region  Unknown_IncomeGroup
# 4          AGO     Sub-Saharan Africa  Lower middle income
# 5          ALB  Europe & Central Asia  Upper middle income
#
#                      tablename
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola
# 5                      Albania

# %%
country_info['incomegroup'].value_counts()
# Out:
# incomegroup
# High income            58
# Lower middle income    54
# Upper middle income    51
# Unknown_IncomeGroup    49
# Low income             26
# Name: count, dtype: int64
